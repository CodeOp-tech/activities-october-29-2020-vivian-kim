# %%
#first way to handle jsondata : saving the file and opening it 
import json
raw1=json.load(open('Financial_data.json'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-124-4dc667fbff3f> in <module>
#       1 #first way to handle jsondata : saving the file and opening it
#       2 import json
# ----> 3 raw1=json.load(open('Financial_data.json'))
#
# TypeError: 'list' object is not callable

# %%
print(raw1)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2020-10-30', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2020-10-30': {'1. open': '107.9000', '2. high': '111.8000', '3. low': '107.7500', '4. close': '111.6600', '5. volume': '7923882'}, '2020-10-29': {'1. open': '107.2500', '2. high': '109.6400', '3. low': '106.5500', '4. close': '108.9100', '5. volume': '6760241'}, '2020-10-28': {'1. open': '108.6600', '2. high': '109.7300', '3. low': '105.9200', '4. close': '106.6500', '5. volume': '9427321'}, '2020-10-27': {'1. open': '112.1500', '2. high': '112.2200', '3. low': '110.0300', '4. close': '110.5600', '5. volume': '5936106'}, '2020-10-26': {'1. open': '114.4500', '2. high': '114.9000', '3. low': '111.8400', '4. close': '112.2200', '5. volume': '7203366'}, '2020-10-23': {'1. open': '116.5000', '2. high': '116.6200', '3. low': '115.5300', '4. close': '116.0000', '5. vo
# ...

# %%
#let's check the tpye of the data
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#second way to import data by requesting it : reading data directly from using url  
import json
import requests 
request=requests.get("https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=IBM&apikey=demo")
#it will get the all the information by using this url
request_text=request.text
#it will read data as string format 
raw2=json.loads(request_text)

# %%
print(raw2)
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': 'IBM', '3. Last Refreshed': '2020-10-30', '4. Output Size': 'Compact', '5. Time Zone': 'US/Eastern'}, 'Time Series (Daily)': {'2020-10-30': {'1. open': '107.9000', '2. high': '111.8000', '3. low': '107.7500', '4. close': '111.6600', '5. volume': '7923882'}, '2020-10-29': {'1. open': '107.2500', '2. high': '109.6400', '3. low': '106.5500', '4. close': '108.9100', '5. volume': '6760241'}, '2020-10-28': {'1. open': '108.6600', '2. high': '109.7300', '3. low': '105.9200', '4. close': '106.6500', '5. volume': '9427321'}, '2020-10-27': {'1. open': '112.1500', '2. high': '112.2200', '3. low': '110.0300', '4. close': '110.5600', '5. volume': '5936106'}, '2020-10-26': {'1. open': '114.4500', '2. high': '114.9000', '3. low': '111.8400', '4. close': '112.2200', '5. volume': '7203366'}, '2020-10-23': {'1. open': '116.5000', '2. high': '116.6200', '3. low': '115.5300', '4. close': '116.0000', '5. vo
# ...

# %%
print(type(raw2))
# Out:
# <class 'dict'>

# %%
#Dumping json format to string variables
#let's put 'separator'
raw2=json.loads(request_text)
data_dump=json.dump(raw2,open('raw2.json',"w"))

# %%
raw3=json.load(open('raw2.json'))

# %%
print(type(raw3))
#it's dictionary
# Out:
# <class 'dict'>

# %%
key_data= raw3["Time Series (Daily)"]

# %%
print(key_data)
# Out:
# {'2020-10-30': {'1. open': '107.9000', '2. high': '111.8000', '3. low': '107.7500', '4. close': '111.6600', '5. volume': '7923882'}, '2020-10-29': {'1. open': '107.2500', '2. high': '109.6400', '3. low': '106.5500', '4. close': '108.9100', '5. volume': '6760241'}, '2020-10-28': {'1. open': '108.6600', '2. high': '109.7300', '3. low': '105.9200', '4. close': '106.6500', '5. volume': '9427321'}, '2020-10-27': {'1. open': '112.1500', '2. high': '112.2200', '3. low': '110.0300', '4. close': '110.5600', '5. volume': '5936106'}, '2020-10-26': {'1. open': '114.4500', '2. high': '114.9000', '3. low': '111.8400', '4. close': '112.2200', '5. volume': '7203366'}, '2020-10-23': {'1. open': '116.5000', '2. high': '116.6200', '3. low': '115.5300', '4. close': '116.0000', '5. volume': '3893362'}, '2020-10-22': {'1. open': '115.0000', '2. high': '116.0600', '3. low': '112.9800', '4. close': '115.7600', '5. volume': '7858158'}, '2020-10-21': {'1. open': '116.6600', '2. high': '117.6899', '3. low': '1
# ...

# %%
pd.DataFrame(key_data)
# Out:
#           2020-10-30 2020-10-29 2020-10-28 2020-10-27 2020-10-26 2020-10-23  \
# 1. open     107.9000   107.2500   108.6600   112.1500   114.4500   116.5000
# 2. high     111.8000   109.6400   109.7300   112.2200   114.9000   116.6200
# 3. low      107.7500   106.5500   105.9200   110.0300   111.8400   115.5300
# 4. close    111.6600   108.9100   106.6500   110.5600   112.2200   116.0000
# 5. volume    7923882    6760241    9427321    5936106    7203366    3893362
#
#           2020-10-22 2020-10-21 2020-10-20 2020-10-19  ... 2020-06-24  \
# 1. open     115.0000   116.6600   119.8000   126.8000  ...   118.3200
# 2. high     116.0600   117.6899   120.1500   127.3500  ...   118.3200
# 3. low      112.9800   114.7900   116.8400   125.0800  ...   115.8800
# 4. close    115.7600   115.0600   117.3700   125.5200  ...   116.4200
# 5. volume    7858158    9755308   21501073    7478735  ...    6751000
#
#           2020-06-23 2020-06-22 2020-06-19 2020-06-18 2020-06-17 2020-06-16  \
# ...
